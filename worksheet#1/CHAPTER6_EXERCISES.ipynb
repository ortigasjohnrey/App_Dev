# %%
# !git config --global user.name = "ortigasjohnrey"
# !git config --global user.email = "ortigas.johnrey@students.isatu.edu.ph"
# !git config --global user.password = "https://ortigasjohnrey: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@github.com/ortigasjohnrey/App_Dev.git"

# %%
# !git clone "https://ortigasjohnrey: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@github.com/ortigasjohnrey/App_Dev.git"
# Out:
# Cloning into 'App_Dev'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 11 (delta 1), reused 10 (delta 0), pack-reused 0
# Receiving objects: 100% (11/11), done.
# Resolving deltas: 100% (1/1), done.

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/CHAPTER6_EXERCISES.ipynb" ""
